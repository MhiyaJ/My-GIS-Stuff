# %% [markdown]
# <a href="https://colab.research.google.com/github/MhiyaJ/My-GIS-Stuff/blob/main/*PS1-%20School%20Districts%20w/%20Municipality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
#!pip install geopandas #==1.0.1
#!pip install mapclassify #sometimes have to install library which you get from https://pypi.org/

# %%
import os, zipfile #basics
import pandas as pd #data management
import matplotlib.pyplot as plt #vis

import geopandas as gpd #gis/maps: a sister of pandas; does the job;
#tho not as fancy-interactive as folium or leafmap https://geopandas.org/

import mapclassify #need for thematic map classification

import seaborn as sns

#will display all output not just last command
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import files #to download from colab onto hd

#from google.colab import data_table
#data_table.enable_dataframe_formatter() #this enables spreadsheet view upon calling dataframe (without() )
from google.colab.data_table import DataTable
DataTable.max_columns = 250

# %%
#!python --version
gpd.__version__
# Out:
# '1.1.4'

# %% [markdown]
# **Hypothesis**: Limited access to affordable after-school programs contributes to increased social disengagement and delinquent behavior among students living in urban areas.

# %% [markdown]
# **Project Description:** Identifying the availability and accessibility of after school programs in low income areas and examining their relationship to youth social disengagement and delinquent behaviors.
#
# *Variables:* After school programs, economically disadvantaged youth population, delinquent/disengaged behavior, household income

# %% [markdown]
# Unified School Districts in NJ - includes and operates primary, secondary and high school as one district

# %% [markdown]
# Census data used to create boundaries for unified school districts.
#
# NJ Office of GIS used Census data to establish unified school district boundaries in two areas, on and near military bases, were edited to reflect special arrangements made for students residing in base housing.
#
# NJDOE used set of grades, based on financial responsibility, to assign the data for each child to exactly one school district, except for districts covering Joint Base McGuire-Dix-Lakehurst in Burlington County.

# %%
#NJ Office of GIS (Jan. 14, 2022), School Districts - Unified for NJ, 3424
#https://njogis-newjersey.opendata.arcgis.com/datasets/newjersey::school-districts-unified-for-nj-3424/about)
#unified school district shown in mp below was made with municipalities in mind
! wget -q -O nj-schools.zip https://github.com/MhiyaJ/My-GIS-Stuff/raw/refs/heads/main/School_Districts___Unified_7341673536716239500.zip

zip_ref = zipfile.ZipFile('nj-schools.zip', 'r'); zip_ref.extractall(); zip_ref.close()

njSch=gpd.read_file('School_Districts_Unified.shp') #labeled shapefile njSch

# %%
njSch.plot()
# Out:
# <Axes: >

# %%
njSch.dtypes #School District Headings
# Out:
# NJDOE_ID_U      object
# DIST_NAME       object
# UNSDLEA         object
# SD_TYPE         object
# GEOID           object
# geometry      geometry
# dtype: object

# %%
#change column names
njSch.rename(columns={'DIST_NAME' : 'District'}, inplace=True)

# %%
#make all upper case
njSch['District'] = njSch['District'].str.upper()

# %%
njSch.columns
# Out:
# Index(['NJDOE_ID_U', 'District', 'UNSDLEA', 'SD_TYPE', 'GEOID', 'geometry'], dtype='object')

# %%
#Googled - Splitting columns into 2, Option 3: Split text and numbers using Regular Expressions
njSch["NJDOE_ID_U"] = njSch["NJDOE_ID_U"].astype(str)
njSch[["CountyCode", "DistrictCode"]] = njSch["NJDOE_ID_U"].str.extract(r"(\d{2}).*(\d{4})")

# %%
#new columns, DistrictCode and CountyCode, with County Code only including Camden County
njSch[njSch['CountyCode'] == '07'][['DistrictCode', 'CountyCode', 'District', 'GEOID']]
# Out:
#     DistrictCode CountyCode  \
# 34          5820         07
# 41          0150         07
# 43          0940         07
# 50          1880         07
# 51          2130         07
# 52          3770         07
# 53          0800         07
# 54          1900         07
# 58          4110         07
# 59          1890         07
# 84          2670         07
# 112         2560         07
# 116         5560         07
# 120         0190         07
# 123         5900         07
# 142         2540         07
# 174         3110         07
# 180         0340         07
# 186         0580         07
# 187         0810         07
# 188         0880         07
# 196         3420         07
# 264         4060         07
# 265         0680         07
# 271         1770         07
#
#                                               District    GEOID
# 34                    WINSLOW TOWNSHIP SCHOOL DISTRICT  3418060
# 41                      AUDUBON PUBLIC SCHOOL DISTRICT  3401050
# 43                 COLLINGSWOOD PUBLIC SCHOOL DISTRICT  3403420
# 50                      HADDON HEIGHTS SCHOOL DISTRICT  3406330
# 51                                            HI NELLA  3407080
# 52                       OAKLYN PUBLIC SCHOOL DISTRICT  3411940
# 53                         CHERRY HILL SCHOOL DISTRICT  3403000
# 54                         HADDONFIELD SCHOOL DISTRICT  3406390
# 58                           PINE HILL SCHOOL DISTRICT  3412990
# 59                     HADDON TOWNSHIP SCHOOL DISTRICT  3406360
# 84                   LINDENWOLD PUBLIC SCHOOL DISTRICT  3408640
# 112                            LAWNSIDE SCHOOL DISTRIC  3408340
# 116                 WATERFORD TOWNSHIP SCHOOL DISTRICT  3417250
# 120                         BARRINGTON SCHOOL DISTRICT  3401170
# 123                          WOODLYNNE SCHOOL DISTRICT  3418270
# 142                     LAUREL SPRINGS SCHOOL DISTRICT  3408280
# 174                      MERCHANTVILLE SCHOOL DISTRICT  3409960
# 180                    BERLIN TOWNSHIP SCHOOL DISTRICT  3401620
# 186                   BROOKLAWN PUBLIC SCHOOL DISTRICT  3402370
# 187                     CHESILHURST BOARD OF EDUCATION  3403030
# 188               CLEMENTON ELEMENTARY SCHOOL DISTRICT  3403240
# 196                        MT. EPHRAIM SCHOOL DISTRICT  3410890
# 264  PENNSAUKEN TOWNSHIP BOARD OF EDUCATION SCHOOL ...  3412870
# 265                        CAMDEN CITY SCHOOL DISTRICT  3402640
# 271             GLOUCESTER CITY PUBLIC SCHOOL DISTRICT  3406000

# %%
DisXls=pd.read_excel ('https://github.com/MhiyaJ/My-GIS-Stuff/raw/refs/heads/main/Economically%20Disadvantage%20Youth.xlsx', header = 3)

# %%
DisXls.dtypes
# Out:
# CountyCode                              int64
# CountyName                             object
# DistrictCode                            int64
# Municpality                            object
# DistrictName                           object
# SchoolYear                             object
# Female                                 object
# Male                                   object
# Non-Binary/Undesignated Gender         object
# Economically Disadvantaged Students    object
# Students with Disabilities             object
# Multilingual Learners                  object
# Students Experiencing Homelessness     object
# Students in Foster Care                object
# Military-Connected Students            object
# Migrant Students                       object
# dtype: object

# %%
DisXls1=DisXls[DisXls['SchoolYear'] =='2024-25'][['CountyName','DistrictCode','DistrictName','Economically Disadvantaged Students']]
DisXls1.rename(columns={'DistrictName' : 'District'}, inplace=True)
DisXls1['District'] = DisXls1['District'].str.upper()
DisXls1
# Out:
#     CountyName  DistrictCode  \
# 4       Camden           150
# 9       Camden           190
# 14      Camden           260
# 19      Camden           330
# 24      Camden           340
# 29      Camden           390
# 34      Camden           580
# 39      Camden           680
# 44      Camden           700
# 49      Camden           800
# 54      Camden           880
# 59      Camden           940
# 64      Camden          1255
# 69      Camden          1720
# 74      Camden          1770
# 79      Camden          1780
# 84      Camden          1799
# 89      Camden          1801
# 94      Camden          1802
# 99      Camden          1880
# 104     Camden          1890
# 109     Camden          1900
# 114     Camden          2540
# 119     Camden          2560
# 124     Camden          2670
# 129     Camden          2890
# 134     Camden          3110
# 139     Camden          3420
# 144     Camden          3770
# 149     Camden          4060
# 154     Camden          4110
# 159     Camden          4590
# 164     Camden          4790
# 169     Camden          5035
# 174     Camden          5080
# 179     Camden          5400
# 184     Camden          5560
# 189     Camden          5820
# 194     Camden          5900
# 199     Camden          6086
# 204     Camden          6107
# 209     Camden          7109
#
#                                               District  \
# 4                       AUDUBON PUBLIC SCHOOL DISTRICT
# 9                           BARRINGTON SCHOOL DISTRICT
# 14                     BELLMAWR PUBLIC SCHOOL DISTRICT
# 19                      BERLIN BOROUGH SCHOOL DISTRICT
# 24                     BERLIN TOWNSHIP SCHOOL DISTRICT
# 29           BLACK HORSE PIKE REGIONAL SCHOOL DISTRICT
# 34                    BROOKLAWN PUBLIC SCHOOL DISTRICT
# 39                         CAMDEN CITY SCHOOL DISTRICT
# 44             CAMDEN COUNTY TECHNICAL SCHOOL DISTRICT
# 49                         CHERRY HILL SCHOOL DISTRICT
# 54                CLEMENTON ELEMENTARY SCHOOL DISTRICT
# 59                 COLLINGSWOOD PUBLIC SCHOOL DISTRICT
# 64      EASTERN CAMDEN COUNTY REGIONAL SCHOOL DISTRICT
# 69                GIBBSBORO ELEMENTARY SCHOOL DISTRICT
# 74              GLOUCESTER CITY PUBLIC SCHOOL DISTRICT
# 79                  GLOUCESTER TOWNSHIP PUBLIC SCHOOLS
# 84   KIPP: COOPER NORCROSS, A NEW JERSEY NONPROFIT ...
# 89                                   CAMDEN PREP, INC.
# 94                     MASTERY SCHOOLS OF CAMDEN, INC.
# 99                      HADDON HEIGHTS SCHOOL DISTRICT
# 104                    HADDON TOWNSHIP SCHOOL DISTRICT
# 109                        HADDONFIELD SCHOOL DISTRICT
# 114                     LAUREL SPRINGS SCHOOL DISTRICT
# 119                           LAWNSIDE SCHOOL DISTRICT
# 124                  LINDENWOLD PUBLIC SCHOOL DISTRICT
# 129                           MAGNOLIA SCHOOL DISTRICT
# 134                      MERCHANTVILLE SCHOOL DISTRICT
# 139                      MOUNT EPHRAIM SCHOOL DISTRICT
# 144                      OAKLYN PUBLIC SCHOOL DISTRICT
# 149  PENNSAUKEN TOWNSHIP BOARD OF EDUCATION SCHOOL ...
# 154                          PINE HILL SCHOOL DISTRICT
# 159                   RUNNEMEDE PUBLIC SCHOOL DISTRICT
# 164                          SOMERDALE SCHOOL DISTRICT
# 169                  STERLING REGIONAL SCHOOL DISTRICT
# 174                          STRATFORD SCHOOL DISTRICT
# 179                  VOORHEES TOWNSHIP SCHOOL DISTRICT
# 184                 WATERFORD TOWNSHIP SCHOOL DISTRICT
# 189                   WINSLOW TOWNSHIP SCHOOL DISTRICT
# 194                          WOODLYNNE SCHOOL DISTRICT
# 199                      HOPE COMMUNITY CHARTER SCHOOL
# 204                    CAMDEN'S PROMISE CHARTER SCHOOL
# 209             LEAP ACADEMY UNIVERSITY CHARTER SCHOOL
#
#     Economically Disadvantaged Students
# 4                                 24.5%
# 9                                 34.1%
# 14                                57.8%
# 19                                25.2%
# 24                                53.3%
# 29                                44.9%
# 34                                70.7%
# 39                                88.5%
# 44                                56.1%
# 49                                23.2%
# 54                                73.4%
# 59                                33.5%
# 64                                19.1%
# 69                                28.6%
# 74                                62.0%
# 79                                47.5%
# 84                                94.4%
# 89                                91.2%
# 94                                95.0%
# 99                                19.3%
# 104                               15.6%
# 109                                2.1%
# 114                               32.1%
# 119                               58.3%
# 124                               81.8%
# 129                               41.6%
# 134                               40.6%
# 139                               42.5%
# 144                               30.7%
# 149                               74.0%
# 154                               72.2%
# 159                               42.3%
# 164                               55.7%
# 169                               38.8%
# 174                               32.3%
# 179                               18.1%
# 184                               35.0%
# 189                               58.6%
# 194                               80.6%
# 199                               91.1%
# 204                               90.1%
# 209                               85.4%

# %%
njSch['DistrictCode'] = njSch['DistrictCode'].astype(str)
DisXls1['DistrictCode'] = DisXls1['DistrictCode'].astype(str).str.zfill(4) # Ensure 4 digits with leading zeros

njSch_filtered = njSch[njSch['CountyCode'] == '07'].copy() # Use .copy() to avoid SettingWithCopyWarning

a1 = pd.merge(njSch_filtered, DisXls1, left_on='DistrictCode', right_on='DistrictCode', how='outer', indicator=True)
a1
# Out:
#    NJDOE_ID_U                                         District_x UNSDLEA  \
# 0     07-0150                     AUDUBON PUBLIC SCHOOL DISTRICT   01050
# 1     07-0190                         BARRINGTON SCHOOL DISTRICT   01170
# 2         NaN                                                NaN     NaN
# 3         NaN                                                NaN     NaN
# 4     07-0340                    BERLIN TOWNSHIP SCHOOL DISTRICT   01620
# 5         NaN                                                NaN     NaN
# 6     07-0580                   BROOKLAWN PUBLIC SCHOOL DISTRICT   02370
# 7     07-0680                        CAMDEN CITY SCHOOL DISTRICT   02640
# 8         NaN                                                NaN     NaN
# 9     07-0800                        CHERRY HILL SCHOOL DISTRICT   03000
# 10    07-0810                     CHESILHURST BOARD OF EDUCATION   03030
# 11    07-0880               CLEMENTON ELEMENTARY SCHOOL DISTRICT   03240
# 12    07-0940                COLLINGSWOOD PUBLIC SCHOOL DISTRICT   03420
# 13        NaN                                                NaN     NaN
# 14        NaN                                                NaN     NaN
# 15    07-1770             GLOUCESTER CITY PUBLIC SCHOOL DISTRICT   06000
# 16        NaN                                                NaN     NaN
# 17        NaN                                                NaN     NaN
# 18        NaN                                                NaN     NaN
# 19        NaN                                                NaN     NaN
# 20    07-1880                     HADDON HEIGHTS SCHOOL DISTRICT   06330
# 21    07-1890                    HADDON TOWNSHIP SCHOOL DISTRICT   06360
# 22    07-1900                        HADDONFIELD SCHOOL DISTRICT   06390
# 23    07-2130                                           HI NELLA   07080
# 24    07-2540                     LAUREL SPRINGS SCHOOL DISTRICT   08280
# 25    07-2560                            LAWNSIDE SCHOOL DISTRIC   08340
# 26    07-2670                  LINDENWOLD PUBLIC SCHOOL DISTRICT   08640
# 27        NaN                                                NaN     NaN
# 28    07-3110                      MERCHANTVILLE SCHOOL DISTRICT   09960
# 29    07-3420                        MT. EPHRAIM SCHOOL DISTRICT   10890
# 30    07-3770                      OAKLYN PUBLIC SCHOOL DISTRICT   11940
# 31    07-4060  PENNSAUKEN TOWNSHIP BOARD OF EDUCATION SCHOOL ...   12870
# 32    07-4110                          PINE HILL SCHOOL DISTRICT   12990
# 33        NaN                                                NaN     NaN
# 34        NaN                                                NaN     NaN
# 35        NaN                                                NaN     NaN
# 36        NaN                                                NaN     NaN
# 37        NaN                                                NaN     NaN
# 38    07-5560                 WATERFORD TOWNSHIP SCHOOL DISTRICT   17250
# 39    07-5820                   WINSLOW TOWNSHIP SCHOOL DISTRICT   18060
# 40    07-5900                          WOODLYNNE SCHOOL DISTRICT   18270
# 41        NaN                                                NaN     NaN
# 42        NaN                                                NaN     NaN
# 43        NaN                                                NaN     NaN
#
#    SD_TYPE    GEOID                                           geometry  \
# 0        U  3401050  POLYGON ((333599.519 389532.256, 334908.018 38...
# 1        U  3401170  POLYGON ((341374.86 382055.06, 341383.46 38191...
# 2      NaN      NaN                                               None
# 3      NaN      NaN                                               None
# 4        U  3401620  POLYGON ((374626.851 357935.944, 375096.547 35...
# 5      NaN      NaN                                               None
# 6        U  3402370  POLYGON ((321421.382 381045.717, 321229.38 381...
# 7        U  3402640  POLYGON ((329538.15 410361.33, 329670.85 41012...
# 8      NaN      NaN                                               None
# 9        U  3403000  POLYGON ((347458.19 406942.14, 347464.79 40692...
# 10       U  3403030  POLYGON ((390827.647 326435.522, 390962.671 32...
# 11       U  3403240  POLYGON ((359476.144 357529.713, 359403.668 35...
# 12       U  3403420  POLYGON ((329936.77 398206.61, 330020.49 39819...
# 13     NaN      NaN                                               None
# 14     NaN      NaN                                               None
# 15       U  3406000  POLYGON ((319281.38 391823.7, 319459.63 391629...
# 16     NaN      NaN                                               None
# 17     NaN      NaN                                               None
# 18     NaN      NaN                                               None
# 19     NaN      NaN                                               None
# 20       U  3406330  POLYGON ((338431.442 383843.61, 338435.82 3836...
# 21       U  3406360  MULTIPOLYGON (((325315.69 389559.475, 325405.0...
# 22       U  3406390  POLYGON ((341402.77 394798.54, 341480.9 394783...
# 23       U  3407080  POLYGON ((346458.121 367972.644, 346568.817 36...
# 24       U  3408280  POLYGON ((352202.822 361778.626, 352218.711 36...
# 25       U  3408340  POLYGON ((346494.735 378987.274, 346980.202 37...
# 26       U  3408640  POLYGON ((355713.504 364878.907, 355718.95 364...
# 27     NaN      NaN                                               None
# 28       U  3409960  POLYGON ((340289.235 407623.084, 340340.31 407...
# 29       U  3410890  POLYGON ((326803.16 384965.534, 326849.22 3849...
# 30       U  3411940  POLYGON ((331980.807 391389.812, 331778.88 391...
# 31       U  3412870  POLYGON ((342763.99 423475.83, 342804.1 423429...
# 32       U  3412990  POLYGON ((351592.589 354425.759, 351577.79 351...
# 33     NaN      NaN                                               None
# 34     NaN      NaN                                               None
# 35     NaN      NaN                                               None
# 36     NaN      NaN                                               None
# 37     NaN      NaN                                               None
# 38       U  3417250  POLYGON ((390010.824 347041.203, 390039.55 347...
# 39       U  3418060  POLYGON ((368609.977 344389.586, 368631.27 344...
# 40       U  3418270  POLYGON ((326156.607 396643.803, 326112.001 39...
# 41     NaN      NaN                                               None
# 42     NaN      NaN                                               None
# 43     NaN      NaN                                               None
#
#    CountyCode DistrictCode CountyName  \
# 0          07         0150     Camden
# 1          07         0190     Camden
# 2         NaN         0260     Camden
# 3         NaN         0330     Camden
# 4          07         0340     Camden
# 5         NaN         0390     Camden
# 6          07         0580     Camden
# 7          07         0680     Camden
# 8         NaN         0700     Camden
# 9          07         0800     Camden
# 10         07         0810        NaN
# 11         07         0880     Camden
# 12         07         0940     Camden
# 13        NaN         1255     Camden
# 14        NaN         1720     Camden
# 15         07         1770     Camden
# 16        NaN         1780     Camden
# 17        NaN         1799     Camden
# 18        NaN         1801     Camden
# 19        NaN         1802     Camden
# 20         07         1880     Camden
# 21         07         1890     Camden
# 22         07         1900     Camden
# 23         07         2130        NaN
# 24         07         2540     Camden
# 25         07         2560     Camden
# 26         07         2670     Camden
# 27        NaN         2890     Camden
# 28         07         3110     Camden
# 29         07         3420     Camden
# 30         07         3770     Camden
# 31         07         4060     Camden
# 32         07         4110     Camden
# 33        NaN         4590     Camden
# 34        NaN         4790     Camden
# 35        NaN         5035     Camden
# 36        NaN         5080     Camden
# 37        NaN         5400     Camden
# 38         07         5560     Camden
# 39         07         5820     Camden
# 40         07         5900     Camden
# 41        NaN         6086     Camden
# 42        NaN         6107     Camden
# 43        NaN         7109     Camden
#
#                                            District_y  \
# 0                      AUDUBON PUBLIC SCHOOL DISTRICT
# 1                          BARRINGTON SCHOOL DISTRICT
# 2                     BELLMAWR PUBLIC SCHOOL DISTRICT
# 3                      BERLIN BOROUGH SCHOOL DISTRICT
# 4                     BERLIN TOWNSHIP SCHOOL DISTRICT
# 5           BLACK HORSE PIKE REGIONAL SCHOOL DISTRICT
# 6                    BROOKLAWN PUBLIC SCHOOL DISTRICT
# 7                         CAMDEN CITY SCHOOL DISTRICT
# 8             CAMDEN COUNTY TECHNICAL SCHOOL DISTRICT
# 9                         CHERRY HILL SCHOOL DISTRICT
# 10                                                NaN
# 11               CLEMENTON ELEMENTARY SCHOOL DISTRICT
# 12                COLLINGSWOOD PUBLIC SCHOOL DISTRICT
# 13     EASTERN CAMDEN COUNTY REGIONAL SCHOOL DISTRICT
# 14               GIBBSBORO ELEMENTARY SCHOOL DISTRICT
# 15             GLOUCESTER CITY PUBLIC SCHOOL DISTRICT
# 16                 GLOUCESTER TOWNSHIP PUBLIC SCHOOLS
# 17  KIPP: COOPER NORCROSS, A NEW JERSEY NONPROFIT ...
# 18                                  CAMDEN PREP, INC.
# 19                    MASTERY SCHOOLS OF CAMDEN, INC.
# 20                     HADDON HEIGHTS SCHOOL DISTRICT
# 21                    HADDON TOWNSHIP SCHOOL DISTRICT
# 22                        HADDONFIELD SCHOOL DISTRICT
# 23                                                NaN
# 24                     LAUREL SPRINGS SCHOOL DISTRICT
# 25                           LAWNSIDE SCHOOL DISTRICT
# 26                  LINDENWOLD PUBLIC SCHOOL DISTRICT
# 27                           MAGNOLIA SCHOOL DISTRICT
# 28                      MERCHANTVILLE SCHOOL DISTRICT
# 29                      MOUNT EPHRAIM SCHOOL DISTRICT
# 30                      OAKLYN PUBLIC SCHOOL DISTRICT
# 31  PENNSAUKEN TOWNSHIP BOARD OF EDUCATION SCHOOL ...
# 32                          PINE HILL SCHOOL DISTRICT
# 33                   RUNNEMEDE PUBLIC SCHOOL DISTRICT
# 34                          SOMERDALE SCHOOL DISTRICT
# 35                  STERLING REGIONAL SCHOOL DISTRICT
# 36                          STRATFORD SCHOOL DISTRICT
# 37                  VOORHEES TOWNSHIP SCHOOL DISTRICT
# 38                 WATERFORD TOWNSHIP SCHOOL DISTRICT
# 39                   WINSLOW TOWNSHIP SCHOOL DISTRICT
# 40                          WOODLYNNE SCHOOL DISTRICT
# 41                      HOPE COMMUNITY CHARTER SCHOOL
# 42                    CAMDEN'S PROMISE CHARTER SCHOOL
# 43             LEAP ACADEMY UNIVERSITY CHARTER SCHOOL
#
#    Economically Disadvantaged Students      _merge
# 0                                24.5%        both
# 1                                34.1%        both
# 2                                57.8%  right_only
# 3                                25.2%  right_only
# 4                                53.3%        both
# 5                                44.9%  right_only
# 6                                70.7%        both
# 7                                88.5%        both
# 8                                56.1%  right_only
# 9                                23.2%        both
# 10                                 NaN   left_only
# 11                               73.4%        both
# 12                               33.5%        both
# 13                               19.1%  right_only
# 14                               28.6%  right_only
# 15                               62.0%        both
# 16                               47.5%  right_only
# 17                               94.4%  right_only
# 18                               91.2%  right_only
# 19                               95.0%  right_only
# 20                               19.3%        both
# 21                               15.6%        both
# 22                                2.1%        both
# 23                                 NaN   left_only
# 24                               32.1%        both
# 25                               58.3%        both
# 26                               81.8%        both
# 27                               41.6%  right_only
# 28                               40.6%        both
# 29                               42.5%        both
# 30                               30.7%        both
# 31                               74.0%        both
# 32                               72.2%        both
# 33                               42.3%  right_only
# 34                               55.7%  right_only
# 35                               38.8%  right_only
# 36                               32.3%  right_only
# 37                               18.1%  right_only
# 38                               35.0%        both
# 39                               58.6%        both
# 40                               80.6%        both
# 41                               91.1%  right_only
# 42                               90.1%  right_only
# 43                               85.4%  right_only

# %%
a1._merge.value_counts()
# Out:
# _merge
# both          23
# right_only    19
# left_only      2
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,8))

# Convert the 'Economically Disadvantaged Students' column to numeric, handling NaN values
a1['Economically Disadvantaged Students'] = a1['Economically Disadvantaged Students'].apply(lambda x: float(x.replace('%', '')) if isinstance(x, str) else x)

a1.plot(ax=ax,figsize=(6,8),column='Economically Disadvantaged Students',legend=True,cmap='YlOrRd',
          scheme='natural_breaks',k=5, edgecolor='black',linewidth=2,legend_kwds= {"fmt": "{:.0f}%"})
ax.set_title('''% of Economically Disadvantaged Students
2024 - 2025 School Year''')
#ax.annotate('Note added to chart with minimum parameters', xy = (200000, 1000))
plt.figtext(0.35, 0.122,
            '''New Jersey, Department of Education
            2024 - 2025 Performance Reports Database - Excel
            Data from https://www.nj.gov/education/spr/download/
            ''',
            ha="center", fontsize=8, #bbox={"facecolor":"white", "alpha":0.5, "pad":5}
            )
# Out:
# <Axes: >
# Text(0.5, 1.0, '% of Economically Disadvantaged Students\n2024 - 2025 School Year')
# Text(0.35, 0.122, 'New Jersey, Department of Education\n            2024 - 2025 Performance Reports Database - Excel\n            Data from https://www.nj.gov/education/spr/download/\n            ')

# %%
DisXls2=DisXls[DisXls['SchoolYear'] =='2023-24'][['CountyName','DistrictCode','DistrictName','Economically Disadvantaged Students']]
DisXls2.rename(columns={'DistrictName' : 'District'}, inplace=True)
DisXls2['District'] = DisXls2['District'].str.upper()
DisXls2
# Out:
#     CountyName  DistrictCode  \
# 3       Camden           150
# 8       Camden           190
# 13      Camden           260
# 18      Camden           330
# 23      Camden           340
# 28      Camden           390
# 33      Camden           580
# 38      Camden           680
# 43      Camden           700
# 48      Camden           800
# 53      Camden           880
# 58      Camden           940
# 63      Camden          1255
# 68      Camden          1720
# 73      Camden          1770
# 78      Camden          1780
# 83      Camden          1799
# 88      Camden          1801
# 93      Camden          1802
# 98      Camden          1880
# 103     Camden          1890
# 108     Camden          1900
# 113     Camden          2540
# 118     Camden          2560
# 123     Camden          2670
# 128     Camden          2890
# 133     Camden          3110
# 138     Camden          3420
# 143     Camden          3770
# 148     Camden          4060
# 153     Camden          4110
# 158     Camden          4590
# 163     Camden          4790
# 168     Camden          5035
# 173     Camden          5080
# 178     Camden          5400
# 183     Camden          5560
# 188     Camden          5820
# 193     Camden          5900
# 198     Camden          6086
# 203     Camden          6107
# 208     Camden          7109
#
#                                               District  \
# 3                       AUDUBON PUBLIC SCHOOL DISTRICT
# 8                           BARRINGTON SCHOOL DISTRICT
# 13                     BELLMAWR PUBLIC SCHOOL DISTRICT
# 18                      BERLIN BOROUGH SCHOOL DISTRICT
# 23                     BERLIN TOWNSHIP SCHOOL DISTRICT
# 28           BLACK HORSE PIKE REGIONAL SCHOOL DISTRICT
# 33                    BROOKLAWN PUBLIC SCHOOL DISTRICT
# 38                         CAMDEN CITY SCHOOL DISTRICT
# 43             CAMDEN COUNTY TECHNICAL SCHOOL DISTRICT
# 48                         CHERRY HILL SCHOOL DISTRICT
# 53                CLEMENTON ELEMENTARY SCHOOL DISTRICT
# 58                 COLLINGSWOOD PUBLIC SCHOOL DISTRICT
# 63      EASTERN CAMDEN COUNTY REGIONAL SCHOOL DISTRICT
# 68                GIBBSBORO ELEMENTARY SCHOOL DISTRICT
# 73              GLOUCESTER CITY PUBLIC SCHOOL DISTRICT
# 78                  GLOUCESTER TOWNSHIP PUBLIC SCHOOLS
# 83   KIPP: COOPER NORCROSS, A NEW JERSEY NONPROFIT ...
# 88                                   CAMDEN PREP, INC.
# 93                     MASTERY SCHOOLS OF CAMDEN, INC.
# 98                      HADDON HEIGHTS SCHOOL DISTRICT
# 103                    HADDON TOWNSHIP SCHOOL DISTRICT
# 108                        HADDONFIELD SCHOOL DISTRICT
# 113                     LAUREL SPRINGS SCHOOL DISTRICT
# 118                           LAWNSIDE SCHOOL DISTRICT
# 123                  LINDENWOLD PUBLIC SCHOOL DISTRICT
# 128                           MAGNOLIA SCHOOL DISTRICT
# 133                      MERCHANTVILLE SCHOOL DISTRICT
# 138                      MOUNT EPHRAIM SCHOOL DISTRICT
# 143                      OAKLYN PUBLIC SCHOOL DISTRICT
# 148  PENNSAUKEN TOWNSHIP BOARD OF EDUCATION SCHOOL ...
# 153                          PINE HILL SCHOOL DISTRICT
# 158                   RUNNEMEDE PUBLIC SCHOOL DISTRICT
# 163                          SOMERDALE SCHOOL DISTRICT
# 168                  STERLING REGIONAL SCHOOL DISTRICT
# 173                          STRATFORD SCHOOL DISTRICT
# 178                  VOORHEES TOWNSHIP SCHOOL DISTRICT
# 183                 WATERFORD TOWNSHIP SCHOOL DISTRICT
# 188                   WINSLOW TOWNSHIP SCHOOL DISTRICT
# 193                          WOODLYNNE SCHOOL DISTRICT
# 198                      HOPE COMMUNITY CHARTER SCHOOL
# 203                    CAMDEN'S PROMISE CHARTER SCHOOL
# 208             LEAP ACADEMY UNIVERSITY CHARTER SCHOOL
#
#     Economically Disadvantaged Students
# 3                                 19.7%
# 8                                 35.5%
# 13                                47.4%
# 18                                17.2%
# 23                                36.4%
# 28                                34.3%
# 33                                67.3%
# 38                                54.7%
# 43                                50.2%
# 48                                18.1%
# 53                                75.0%
# 58                                29.5%
# 63                                14.9%
# 68                                24.7%
# 73                                39.4%
# 78                                42.0%
# 83                                93.0%
# 88                                59.5%
# 93                                96.8%
# 98                                14.0%
# 103                               12.6%
# 108                                1.9%
# 113                               27.3%
# 118                               56.4%
# 123                               75.7%
# 128                               38.8%
# 133                               38.5%
# 138                               40.5%
# 143                               26.2%
# 148                               66.3%
# 153                               63.7%
# 158                               32.7%
# 163                               40.0%
# 168                               32.9%
# 173                               35.6%
# 178                               12.3%
# 183                               29.0%
# 188                               53.9%
# 193                               86.5%
# 198                               94.4%
# 203                               90.1%
# 208                               87.9%

# %%
njSch['DistrictCode'] = njSch['DistrictCode'].astype(str)
DisXls2['DistrictCode'] = DisXls2['DistrictCode'].astype(str).str.zfill(4) # Ensure 4 digits with leading zeros

njSch_filtered = njSch[njSch['CountyCode'] == '07'].copy() # Use .copy() to avoid SettingWithCopyWarning

a1 = pd.merge(njSch_filtered, DisXls2, left_on='DistrictCode', right_on='DistrictCode', how='outer', indicator=True)
a1
# Out:
#    NJDOE_ID_U                                         District_x UNSDLEA  \
# 0     07-0150                     AUDUBON PUBLIC SCHOOL DISTRICT   01050
# 1     07-0190                         BARRINGTON SCHOOL DISTRICT   01170
# 2         NaN                                                NaN     NaN
# 3         NaN                                                NaN     NaN
# 4     07-0340                    BERLIN TOWNSHIP SCHOOL DISTRICT   01620
# 5         NaN                                                NaN     NaN
# 6     07-0580                   BROOKLAWN PUBLIC SCHOOL DISTRICT   02370
# 7     07-0680                        CAMDEN CITY SCHOOL DISTRICT   02640
# 8         NaN                                                NaN     NaN
# 9     07-0800                        CHERRY HILL SCHOOL DISTRICT   03000
# 10    07-0810                     CHESILHURST BOARD OF EDUCATION   03030
# 11    07-0880               CLEMENTON ELEMENTARY SCHOOL DISTRICT   03240
# 12    07-0940                COLLINGSWOOD PUBLIC SCHOOL DISTRICT   03420
# 13        NaN                                                NaN     NaN
# 14        NaN                                                NaN     NaN
# 15    07-1770             GLOUCESTER CITY PUBLIC SCHOOL DISTRICT   06000
# 16        NaN                                                NaN     NaN
# 17        NaN                                                NaN     NaN
# 18        NaN                                                NaN     NaN
# 19        NaN                                                NaN     NaN
# 20    07-1880                     HADDON HEIGHTS SCHOOL DISTRICT   06330
# 21    07-1890                    HADDON TOWNSHIP SCHOOL DISTRICT   06360
# 22    07-1900                        HADDONFIELD SCHOOL DISTRICT   06390
# 23    07-2130                                           HI NELLA   07080
# 24    07-2540                     LAUREL SPRINGS SCHOOL DISTRICT   08280
# 25    07-2560                            LAWNSIDE SCHOOL DISTRIC   08340
# 26    07-2670                  LINDENWOLD PUBLIC SCHOOL DISTRICT   08640
# 27        NaN                                                NaN     NaN
# 28    07-3110                      MERCHANTVILLE SCHOOL DISTRICT   09960
# 29    07-3420                        MT. EPHRAIM SCHOOL DISTRICT   10890
# 30    07-3770                      OAKLYN PUBLIC SCHOOL DISTRICT   11940
# 31    07-4060  PENNSAUKEN TOWNSHIP BOARD OF EDUCATION SCHOOL ...   12870
# 32    07-4110                          PINE HILL SCHOOL DISTRICT   12990
# 33        NaN                                                NaN     NaN
# 34        NaN                                                NaN     NaN
# 35        NaN                                                NaN     NaN
# 36        NaN                                                NaN     NaN
# 37        NaN                                                NaN     NaN
# 38    07-5560                 WATERFORD TOWNSHIP SCHOOL DISTRICT   17250
# 39    07-5820                   WINSLOW TOWNSHIP SCHOOL DISTRICT   18060
# 40    07-5900                          WOODLYNNE SCHOOL DISTRICT   18270
# 41        NaN                                                NaN     NaN
# 42        NaN                                                NaN     NaN
# 43        NaN                                                NaN     NaN
#
#    SD_TYPE    GEOID                                           geometry  \
# 0        U  3401050  POLYGON ((333599.519 389532.256, 334908.018 38...
# 1        U  3401170  POLYGON ((341374.86 382055.06, 341383.46 38191...
# 2      NaN      NaN                                               None
# 3      NaN      NaN                                               None
# 4        U  3401620  POLYGON ((374626.851 357935.944, 375096.547 35...
# 5      NaN      NaN                                               None
# 6        U  3402370  POLYGON ((321421.382 381045.717, 321229.38 381...
# 7        U  3402640  POLYGON ((329538.15 410361.33, 329670.85 41012...
# 8      NaN      NaN                                               None
# 9        U  3403000  POLYGON ((347458.19 406942.14, 347464.79 40692...
# 10       U  3403030  POLYGON ((390827.647 326435.522, 390962.671 32...
# 11       U  3403240  POLYGON ((359476.144 357529.713, 359403.668 35...
# 12       U  3403420  POLYGON ((329936.77 398206.61, 330020.49 39819...
# 13     NaN      NaN                                               None
# 14     NaN      NaN                                               None
# 15       U  3406000  POLYGON ((319281.38 391823.7, 319459.63 391629...
# 16     NaN      NaN                                               None
# 17     NaN      NaN                                               None
# 18     NaN      NaN                                               None
# 19     NaN      NaN                                               None
# 20       U  3406330  POLYGON ((338431.442 383843.61, 338435.82 3836...
# 21       U  3406360  MULTIPOLYGON (((325315.69 389559.475, 325405.0...
# 22       U  3406390  POLYGON ((341402.77 394798.54, 341480.9 394783...
# 23       U  3407080  POLYGON ((346458.121 367972.644, 346568.817 36...
# 24       U  3408280  POLYGON ((352202.822 361778.626, 352218.711 36...
# 25       U  3408340  POLYGON ((346494.735 378987.274, 346980.202 37...
# 26       U  3408640  POLYGON ((355713.504 364878.907, 355718.95 364...
# 27     NaN      NaN                                               None
# 28       U  3409960  POLYGON ((340289.235 407623.084, 340340.31 407...
# 29       U  3410890  POLYGON ((326803.16 384965.534, 326849.22 3849...
# 30       U  3411940  POLYGON ((331980.807 391389.812, 331778.88 391...
# 31       U  3412870  POLYGON ((342763.99 423475.83, 342804.1 423429...
# 32       U  3412990  POLYGON ((351592.589 354425.759, 351577.79 351...
# 33     NaN      NaN                                               None
# 34     NaN      NaN                                               None
# 35     NaN      NaN                                               None
# 36     NaN      NaN                                               None
# 37     NaN      NaN                                               None
# 38       U  3417250  POLYGON ((390010.824 347041.203, 390039.55 347...
# 39       U  3418060  POLYGON ((368609.977 344389.586, 368631.27 344...
# 40       U  3418270  POLYGON ((326156.607 396643.803, 326112.001 39...
# 41     NaN      NaN                                               None
# 42     NaN      NaN                                               None
# 43     NaN      NaN                                               None
#
#    CountyCode DistrictCode CountyName  \
# 0          07         0150     Camden
# 1          07         0190     Camden
# 2         NaN         0260     Camden
# 3         NaN         0330     Camden
# 4          07         0340     Camden
# 5         NaN         0390     Camden
# 6          07         0580     Camden
# 7          07         0680     Camden
# 8         NaN         0700     Camden
# 9          07         0800     Camden
# 10         07         0810        NaN
# 11         07         0880     Camden
# 12         07         0940     Camden
# 13        NaN         1255     Camden
# 14        NaN         1720     Camden
# 15         07         1770     Camden
# 16        NaN         1780     Camden
# 17        NaN         1799     Camden
# 18        NaN         1801     Camden
# 19        NaN         1802     Camden
# 20         07         1880     Camden
# 21         07         1890     Camden
# 22         07         1900     Camden
# 23         07         2130        NaN
# 24         07         2540     Camden
# 25         07         2560     Camden
# 26         07         2670     Camden
# 27        NaN         2890     Camden
# 28         07         3110     Camden
# 29         07         3420     Camden
# 30         07         3770     Camden
# 31         07         4060     Camden
# 32         07         4110     Camden
# 33        NaN         4590     Camden
# 34        NaN         4790     Camden
# 35        NaN         5035     Camden
# 36        NaN         5080     Camden
# 37        NaN         5400     Camden
# 38         07         5560     Camden
# 39         07         5820     Camden
# 40         07         5900     Camden
# 41        NaN         6086     Camden
# 42        NaN         6107     Camden
# 43        NaN         7109     Camden
#
#                                            District_y  \
# 0                      AUDUBON PUBLIC SCHOOL DISTRICT
# 1                          BARRINGTON SCHOOL DISTRICT
# 2                     BELLMAWR PUBLIC SCHOOL DISTRICT
# 3                      BERLIN BOROUGH SCHOOL DISTRICT
# 4                     BERLIN TOWNSHIP SCHOOL DISTRICT
# 5           BLACK HORSE PIKE REGIONAL SCHOOL DISTRICT
# 6                    BROOKLAWN PUBLIC SCHOOL DISTRICT
# 7                         CAMDEN CITY SCHOOL DISTRICT
# 8             CAMDEN COUNTY TECHNICAL SCHOOL DISTRICT
# 9                         CHERRY HILL SCHOOL DISTRICT
# 10                                                NaN
# 11               CLEMENTON ELEMENTARY SCHOOL DISTRICT
# 12                COLLINGSWOOD PUBLIC SCHOOL DISTRICT
# 13     EASTERN CAMDEN COUNTY REGIONAL SCHOOL DISTRICT
# 14               GIBBSBORO ELEMENTARY SCHOOL DISTRICT
# 15             GLOUCESTER CITY PUBLIC SCHOOL DISTRICT
# 16                 GLOUCESTER TOWNSHIP PUBLIC SCHOOLS
# 17  KIPP: COOPER NORCROSS, A NEW JERSEY NONPROFIT ...
# 18                                  CAMDEN PREP, INC.
# 19                    MASTERY SCHOOLS OF CAMDEN, INC.
# 20                     HADDON HEIGHTS SCHOOL DISTRICT
# 21                    HADDON TOWNSHIP SCHOOL DISTRICT
# 22                        HADDONFIELD SCHOOL DISTRICT
# 23                                                NaN
# 24                     LAUREL SPRINGS SCHOOL DISTRICT
# 25                           LAWNSIDE SCHOOL DISTRICT
# 26                  LINDENWOLD PUBLIC SCHOOL DISTRICT
# 27                           MAGNOLIA SCHOOL DISTRICT
# 28                      MERCHANTVILLE SCHOOL DISTRICT
# 29                      MOUNT EPHRAIM SCHOOL DISTRICT
# 30                      OAKLYN PUBLIC SCHOOL DISTRICT
# 31  PENNSAUKEN TOWNSHIP BOARD OF EDUCATION SCHOOL ...
# 32                          PINE HILL SCHOOL DISTRICT
# 33                   RUNNEMEDE PUBLIC SCHOOL DISTRICT
# 34                          SOMERDALE SCHOOL DISTRICT
# 35                  STERLING REGIONAL SCHOOL DISTRICT
# 36                          STRATFORD SCHOOL DISTRICT
# 37                  VOORHEES TOWNSHIP SCHOOL DISTRICT
# 38                 WATERFORD TOWNSHIP SCHOOL DISTRICT
# 39                   WINSLOW TOWNSHIP SCHOOL DISTRICT
# 40                          WOODLYNNE SCHOOL DISTRICT
# 41                      HOPE COMMUNITY CHARTER SCHOOL
# 42                    CAMDEN'S PROMISE CHARTER SCHOOL
# 43             LEAP ACADEMY UNIVERSITY CHARTER SCHOOL
#
#    Economically Disadvantaged Students      _merge
# 0                                19.7%        both
# 1                                35.5%        both
# 2                                47.4%  right_only
# 3                                17.2%  right_only
# 4                                36.4%        both
# 5                                34.3%  right_only
# 6                                67.3%        both
# 7                                54.7%        both
# 8                                50.2%  right_only
# 9                                18.1%        both
# 10                                 NaN   left_only
# 11                               75.0%        both
# 12                               29.5%        both
# 13                               14.9%  right_only
# 14                               24.7%  right_only
# 15                               39.4%        both
# 16                               42.0%  right_only
# 17                               93.0%  right_only
# 18                               59.5%  right_only
# 19                               96.8%  right_only
# 20                               14.0%        both
# 21                               12.6%        both
# 22                                1.9%        both
# 23                                 NaN   left_only
# 24                               27.3%        both
# 25                               56.4%        both
# 26                               75.7%        both
# 27                               38.8%  right_only
# 28                               38.5%        both
# 29                               40.5%        both
# 30                               26.2%        both
# 31                               66.3%        both
# 32                               63.7%        both
# 33                               32.7%  right_only
# 34                               40.0%  right_only
# 35                               32.9%  right_only
# 36                               35.6%  right_only
# 37                               12.3%  right_only
# 38                               29.0%        both
# 39                               53.9%        both
# 40                               86.5%        both
# 41                               94.4%  right_only
# 42                               90.1%  right_only
# 43                               87.9%  right_only

# %%
a1._merge.value_counts()
# Out:
# _merge
# both          23
# right_only    19
# left_only      2
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,8))

# Convert the 'Economically Disadvantaged Students' column to numeric, handling NaN values
a1['Economically Disadvantaged Students'] = a1['Economically Disadvantaged Students'].apply(lambda x: float(x.replace('%', '')) if isinstance(x, str) else x)

a1.plot(ax=ax,figsize=(6,8),column='Economically Disadvantaged Students',legend=True,cmap='YlOrRd',
          scheme='natural_breaks',k=5, edgecolor='black',linewidth=2,legend_kwds= {"fmt": "{:.0f}%"})
ax.set_title('''% of Economically Disadvantaged Students
2023 - 2024 School Year''')
#ax.annotate('Note added to chart with minimum parameters', xy = (200000, 1000))
plt.figtext(0.35, 0.122,
            '''New Jersey, Department of Education
            2024 - 2025 Performance Reports Database - Excel
            Data from https://www.nj.gov/education/spr/download/
            ''',
            ha="center", fontsize=8, #bbox={"facecolor":"white", "alpha":0.5, "pad":5}
            )
# Out:
# <Axes: >
# Text(0.5, 1.0, '% of Economically Disadvantaged Students\n2023 - 2024 School Year')
# Text(0.35, 0.122, 'New Jersey, Department of Education\n            2024 - 2025 Performance Reports Database - Excel\n            Data from https://www.nj.gov/education/spr/download/\n            ')

# %%
njSch['DistrictCode'] = njSch['DistrictCode'].astype(str)
DisXls1['DistrictCode'] = DisXls1['DistrictCode'].astype(str).str.zfill(4) # Ensure 4 digits with leading zeros

njSch_filtered = njSch[njSch['CountyCode'] == '07'].copy() # Use .copy() to avoid SettingWithCopyWarning
njSch_filtered['District'] = njSch_filtered['District'].str.split().str[:2].str.join(' ')

DisXls1['District'] = DisXls1['District'].str.split().str[:2].str.join(' ') # Apply to DisXls1 as well

a1 = pd.merge(njSch_filtered, DisXls1, left_on=['DistrictCode','District'], right_on=['DistrictCode','District'], how='outer', indicator=True)
a1
# Out:
#    NJDOE_ID_U              District UNSDLEA SD_TYPE    GEOID  \
# 0     07-0150        AUDUBON PUBLIC   01050       U  3401050
# 1     07-0190     BARRINGTON SCHOOL   01170       U  3401170
# 2         NaN       BELLMAWR PUBLIC     NaN     NaN      NaN
# 3         NaN        BERLIN BOROUGH     NaN     NaN      NaN
# 4     07-0340       BERLIN TOWNSHIP   01620       U  3401620
# 5         NaN           BLACK HORSE     NaN     NaN      NaN
# 6     07-0580      BROOKLAWN PUBLIC   02370       U  3402370
# 7     07-0680           CAMDEN CITY   02640       U  3402640
# 8         NaN         CAMDEN COUNTY     NaN     NaN      NaN
# 9     07-0800           CHERRY HILL   03000       U  3403000
# 10    07-0810     CHESILHURST BOARD   03030       U  3403030
# 11    07-0880  CLEMENTON ELEMENTARY   03240       U  3403240
# 12    07-0940   COLLINGSWOOD PUBLIC   03420       U  3403420
# 13        NaN        EASTERN CAMDEN     NaN     NaN      NaN
# 14        NaN  GIBBSBORO ELEMENTARY     NaN     NaN      NaN
# 15    07-1770       GLOUCESTER CITY   06000       U  3406000
# 16        NaN   GLOUCESTER TOWNSHIP     NaN     NaN      NaN
# 17        NaN          KIPP: COOPER     NaN     NaN      NaN
# 18        NaN          CAMDEN PREP,     NaN     NaN      NaN
# 19        NaN       MASTERY SCHOOLS     NaN     NaN      NaN
# 20    07-1880        HADDON HEIGHTS   06330       U  3406330
# 21    07-1890       HADDON TOWNSHIP   06360       U  3406360
# 22    07-1900    HADDONFIELD SCHOOL   06390       U  3406390
# 23    07-2130              HI NELLA   07080       U  3407080
# 24    07-2540        LAUREL SPRINGS   08280       U  3408280
# 25    07-2560       LAWNSIDE SCHOOL   08340       U  3408340
# 26    07-2670     LINDENWOLD PUBLIC   08640       U  3408640
# 27        NaN       MAGNOLIA SCHOOL     NaN     NaN      NaN
# 28    07-3110  MERCHANTVILLE SCHOOL   09960       U  3409960
# 29        NaN         MOUNT EPHRAIM     NaN     NaN      NaN
# 30    07-3420           MT. EPHRAIM   10890       U  3410890
# 31    07-3770         OAKLYN PUBLIC   11940       U  3411940
# 32    07-4060   PENNSAUKEN TOWNSHIP   12870       U  3412870
# 33    07-4110             PINE HILL   12990       U  3412990
# 34        NaN      RUNNEMEDE PUBLIC     NaN     NaN      NaN
# 35        NaN      SOMERDALE SCHOOL     NaN     NaN      NaN
# 36        NaN     STERLING REGIONAL     NaN     NaN      NaN
# 37        NaN      STRATFORD SCHOOL     NaN     NaN      NaN
# 38        NaN     VOORHEES TOWNSHIP     NaN     NaN      NaN
# 39    07-5560    WATERFORD TOWNSHIP   17250       U  3417250
# 40    07-5820      WINSLOW TOWNSHIP   18060       U  3418060
# 41    07-5900      WOODLYNNE SCHOOL   18270       U  3418270
# 42        NaN        HOPE COMMUNITY     NaN     NaN      NaN
# 43        NaN      CAMDEN'S PROMISE     NaN     NaN      NaN
# 44        NaN          LEAP ACADEMY     NaN     NaN      NaN
#
#                                              geometry CountyCode DistrictCode  \
# 0   POLYGON ((333599.519 389532.256, 334908.018 38...         07         0150
# 1   POLYGON ((341374.86 382055.06, 341383.46 38191...         07         0190
# 2                                                None        NaN         0260
# 3                                                None        NaN         0330
# 4   POLYGON ((374626.851 357935.944, 375096.547 35...         07         0340
# 5                                                None        NaN         0390
# 6   POLYGON ((321421.382 381045.717, 321229.38 381...         07         0580
# 7   POLYGON ((329538.15 410361.33, 329670.85 41012...         07         0680
# 8                                                None        NaN         0700
# 9   POLYGON ((347458.19 406942.14, 347464.79 40692...         07         0800
# 10  POLYGON ((390827.647 326435.522, 390962.671 32...         07         0810
# 11  POLYGON ((359476.144 357529.713, 359403.668 35...         07         0880
# 12  POLYGON ((329936.77 398206.61, 330020.49 39819...         07         0940
# 13                                               None        NaN         1255
# 14                                               None        NaN         1720
# 15  POLYGON ((319281.38 391823.7, 319459.63 391629...         07         1770
# 16                                               None        NaN         1780
# 17                                               None        NaN         1799
# 18                                               None        NaN         1801
# 19                                               None        NaN         1802
# 20  POLYGON ((338431.442 383843.61, 338435.82 3836...         07         1880
# 21  MULTIPOLYGON (((325315.69 389559.475, 325405.0...         07         1890
# 22  POLYGON ((341402.77 394798.54, 341480.9 394783...         07         1900
# 23  POLYGON ((346458.121 367972.644, 346568.817 36...         07         2130
# 24  POLYGON ((352202.822 361778.626, 352218.711 36...         07         2540
# 25  POLYGON ((346494.735 378987.274, 346980.202 37...         07         2560
# 26  POLYGON ((355713.504 364878.907, 355718.95 364...         07         2670
# 27                                               None        NaN         2890
# 28  POLYGON ((340289.235 407623.084, 340340.31 407...         07         3110
# 29                                               None        NaN         3420
# 30  POLYGON ((326803.16 384965.534, 326849.22 3849...         07         3420
# 31  POLYGON ((331980.807 391389.812, 331778.88 391...         07         3770
# 32  POLYGON ((342763.99 423475.83, 342804.1 423429...         07         4060
# 33  POLYGON ((351592.589 354425.759, 351577.79 351...         07         4110
# 34                                               None        NaN         4590
# 35                                               None        NaN         4790
# 36                                               None        NaN         5035
# 37                                               None        NaN         5080
# 38                                               None        NaN         5400
# 39  POLYGON ((390010.824 347041.203, 390039.55 347...         07         5560
# 40  POLYGON ((368609.977 344389.586, 368631.27 344...         07         5820
# 41  POLYGON ((326156.607 396643.803, 326112.001 39...         07         5900
# 42                                               None        NaN         6086
# 43                                               None        NaN         6107
# 44                                               None        NaN         7109
#
#    CountyName Economically Disadvantaged Students      _merge
# 0      Camden                               24.5%        both
# 1      Camden                               34.1%        both
# 2      Camden                               57.8%  right_only
# 3      Camden                               25.2%  right_only
# 4      Camden                               53.3%        both
# 5      Camden                               44.9%  right_only
# 6      Camden                               70.7%        both
# 7      Camden                               88.5%        both
# 8      Camden                               56.1%  right_only
# 9      Camden                               23.2%        both
# 10        NaN                                 NaN   left_only
# 11     Camden                               73.4%        both
# 12     Camden                               33.5%        both
# 13     Camden                               19.1%  right_only
# 14     Camden                               28.6%  right_only
# 15     Camden                               62.0%        both
# 16     Camden                               47.5%  right_only
# 17     Camden                               94.4%  right_only
# 18     Camden                               91.2%  right_only
# 19     Camden                               95.0%  right_only
# 20     Camden                               19.3%        both
# 21     Camden                               15.6%        both
# 22     Camden                                2.1%        both
# 23        NaN                                 NaN   left_only
# 24     Camden                               32.1%        both
# 25     Camden                               58.3%        both
# 26     Camden                               81.8%        both
# 27     Camden                               41.6%  right_only
# 28     Camden                               40.6%        both
# 29     Camden                               42.5%  right_only
# 30        NaN                                 NaN   left_only
# 31     Camden                               30.7%        both
# 32     Camden                               74.0%        both
# 33     Camden                               72.2%        both
# 34     Camden                               42.3%  right_only
# 35     Camden                               55.7%  right_only
# 36     Camden                               38.8%  right_only
# 37     Camden                               32.3%  right_only
# 38     Camden                               18.1%  right_only
# 39     Camden                               35.0%        both
# 40     Camden                               58.6%        both
# 41     Camden                               80.6%        both
# 42     Camden                               91.1%  right_only
# 43     Camden                               90.1%  right_only
# 44     Camden                               85.4%  right_only

# %%
a1._merge.value_counts()
# Out:
# _merge
# both          22
# right_only    20
# left_only      3
# Name: count, dtype: int64

# %%
#I thought this was neat showing bar graph of just right :-), Gemini assisted
import seaborn as sns
import matplotlib.pyplot as plt

# Sort the DataFrame by 'Economically Disadvantaged Students' for better visualization
a1_right_only_sorted = a1_right_only.sort_values(by='Economically Disadvantaged Students', ascending=False)

fig, ax = plt.subplots(figsize=(10, 8))
sns.barplot(x='Economically Disadvantaged Students', y='District', data=a1_right_only_sorted, palette='viridis', ax=ax)
ax.set_title('% of Economically Disadvantaged Students (Right Only)\n2024 - 2025 School Year')
ax.set_xlabel('Economically Disadvantaged Students (%)')
ax.set_ylabel('District')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3317/2766468551.py in <cell line: 0>()
#       4
#       5 # Sort the DataFrame by 'Economically Disadvantaged Students' for better visualization
# ----> 6 a1_right_only_sorted = a1_right_only.sort_values(by='Economically Disadvantaged Students', ascending=False)
#       7
#       8 fig, ax = plt.subplots(figsize=(10, 8))
#
# NameError: name 'a1_right_only' is not defined
