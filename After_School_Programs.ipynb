# %% [markdown]
# <a href="https://colab.research.google.com/github/MhiyaJ/My-GIS-Stuff/blob/main/After_School_Programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
#!pip install geopandas #==1.0.1
#!pip install mapclassify #sometimes have to install library which you get from https://pypi.org/

# %%
import os, zipfile #basics
import pandas as pd #data management
import matplotlib.pyplot as plt #vis

import geopandas as gpd #gis/maps: a sister of pandas; does the job;
#tho not as fancy-interactive as folium or leafmap https://geopandas.org/

import mapclassify #need for thematic map classification

import seaborn as sns

#will display all output not just last command
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import files #to download from colab onto hd

#from google.colab import data_table
#data_table.enable_dataframe_formatter() #this enables spreadsheet view upon calling dataframe (without() )
from google.colab.data_table import DataTable
DataTable.max_columns = 250

# %%
#!python --version
gpd.__version__
# Out:
# '1.1.4'

# %% [markdown]
# **Hypothesis**: Limited access to affordable after-school programs contributes to increased social disengagement and delinquent behavior among students living in urban areas.
#
# *Variables:* After school programs, Youth population, delinquent/disengaged behavior, household income

# %% [markdown]
# Unified School Districts in NJ - includes and operates primary, secondary and high school as one district

# %%
#used same code, changed website link to School Districts - Unified for NJ, 3424 from NJ Office of GIS (Jan. 14, 2022)
#https://njogis-newjersey.opendata.arcgis.com/datasets/newjersey::school-districts-unified-for-nj-3424/about):

! wget -q -O nj-census.zip https://github.com/MhiyaJ/My-GIS-Stuff/raw/refs/heads/main/tl_2023_34_unsd.zip

zip_ref = zipfile.ZipFile ('nj-census.zip', 'r'); zip_ref.extractall(); zip_ref.close() #look for zip drive

njCen=gpd.read_file('tl_2023_34_unsd.shp') #look for shapefile (shp.), labeled shapefile njSch

# %%
njCen.plot()
#school district boundaries in two areas, on and near military bases, were edited to reflect special arrangements made for students residing in base housing
#NJDOE used set of grades, based on financial responsibility, to assign the data for each child to exactly one school district, except for districts covering Joint Base McGuire-Dix-Lakehurst in Burlington County
# Out:
# <Axes: >

# %%
#unified school district made with municipalities in mind
! wget -q -O nj-counties.zip https://github.com/theaok/data/raw/refs/heads/main/bounds_nj_shp.zip

zip_ref = zipfile.ZipFile('nj-counties.zip', 'r'); zip_ref.extractall(); zip_ref.close()

njC0=gpd.read_file('nj_munis.shp')
