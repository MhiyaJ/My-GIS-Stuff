# %% [markdown]
# <a href="https://colab.research.google.com/github/MhiyaJ/My-GIS-Stuff/blob/main/School%20District%20Merge%20(ps01).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
#!pip install geopandas #==1.0.1
#!pip install mapclassify #sometimes have to install library which you get from https://pypi.org/

# %%
import os, zipfile #basics
import pandas as pd #data management
import matplotlib.pyplot as plt #vis

import geopandas as gpd #gis/maps: a sister of pandas; does the job;
#tho not as fancy-interactive as folium or leafmap https://geopandas.org/

import mapclassify #need for thematic map classification

import seaborn as sns

#will display all output not just last command
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import files #to download from colab onto hd

#from google.colab import data_table
#data_table.enable_dataframe_formatter() #this enables spreadsheet view upon calling dataframe (without() )
from google.colab.data_table import DataTable
DataTable.max_columns = 250

# %%
#!python --version
gpd.__version__
# Out:
# '1.1.4'

# %% [markdown]
# **Hypothesis**: Limited access to affordable after-school programs contributes to increased social disengagement and delinquent behavior among students living in urban areas.

# %% [markdown]
# **Project Description:** Identifying the availability and accessibility of after school programs in low income areas and examining their relationship to youth social disengagement and delinquent behaviors.
#
# *Variables:* After school programs, economically disadvantaged youth population, delinquent/disengaged behavior, household income

# %% [markdown]
# Unified School Districts in NJ - includes and operates primary, secondary and high school as one district

# %% [markdown]
# Census data used to create boundaries for unified school districts.
#
# NJ Office of GIS used Census data to establish unified school district boundaries in two areas, on and near military bases, were edited to reflect special arrangements made for students residing in base housing.
#
# NJDOE used set of grades, based on financial responsibility, to assign the data for each child to exactly one school district, except for districts covering Joint Base McGuire-Dix-Lakehurst in Burlington County.

# %%
#NJ Office of GIS (Jan. 14, 2022), School Districts - Unified for NJ, 3424
#https://njogis-newjersey.opendata.arcgis.com/datasets/newjersey::school-districts-unified-for-nj-3424/about)
#unified school district shown in mp below was made with municipalities in mind
! wget -q -O nj-schools.zip https://github.com/MhiyaJ/My-GIS-Stuff/raw/refs/heads/main/School_Districts___Unified_7341673536716239500.zip

zip_ref = zipfile.ZipFile('nj-schools.zip', 'r'); zip_ref.extractall(); zip_ref.close()

njSch=gpd.read_file('School_Districts_Unified.shp') #labeled shapefile njSch

# %%
njSch.plot()
# Out:
# <Axes: >

# %%
len(njSch)
# Out:
# 339

# %%
njSch.dtypes #School District Headings
# Out:
# NJDOE_ID_U      object
# DIST_NAME       object
# UNSDLEA         object
# SD_TYPE         object
# GEOID           object
# geometry      geometry
# dtype: object

# %%
DisXls=pd.read_excel ('https://github.com/MhiyaJ/My-GIS-Stuff/raw/refs/heads/main/Economically%20Disadvantage%20Youth%202024%20-%202025.xlsx', header = 3)

# %%
len(DisXls)
# Out:
# 41

# %%
DisXls.dtypes
# Out:
# CountyCode                              int64
# CountyName                             object
# DistrictCode                            int64
# DistrictName                           object
# SchoolYear                             object
# Female                                 object
# Male                                   object
# Non-Binary/Undesignated Gender         object
# Economically Disadvantaged Students    object
# Students with Disabilities             object
# Multilingual Learners                  object
# Students Experiencing Homelessness     object
# Students in Foster Care                object
# Military-Connected Students            object
# Migrant Students                       object
# dtype: object

# %%
DisXls1=DisXls [['CountyName','DistrictName','Economically Disadvantaged Students']]
DisXls1.rename(columns={'DistrictName' : 'DIST_NAME'}, inplace=True)
DisXls1
# Out:
# /tmp/ipykernel_1205/1806286204.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DisXls1.rename(columns={'DistrictName' : 'DIST_NAME'}, inplace=True)
#    CountyName                                          DIST_NAME  \
# 0      Camden                     Audubon Public School District
# 1      Camden                         Barrington School District
# 2      Camden                    Bellmawr Public School District
# 3      Camden                     Berlin Borough School District
# 4      Camden                    Berlin Township School District
# 5      Camden          Black Horse Pike Regional School District
# 6      Camden                   Brooklawn Public School District
# 7      Camden                        Camden City School District
# 8      Camden            Camden County Technical School District
# 9      Camden                        Cherry Hill School District
# 10     Camden               Clementon Elementary School District
# 11     Camden                Collingswood Public School District
# 12     Camden     Eastern Camden County Regional School District
# 13     Camden               Gibbsboro Elementary School District
# 14     Camden                 Gloucester Township Public Schools
# 15     Camden  KIPP: Cooper Norcross, A New Jersey Nonprofit ...
# 16     Camden                                  Camden Prep, Inc.
# 17     Camden                    Mastery Schools of Camden, Inc.
# 18     Camden                     Haddon Heights School District
# 19     Camden                    Haddon Township School District
# 20     Camden                        Haddonfield School District
# 21     Camden                     Laurel Springs School District
# 22     Camden                           Lawnside School District
# 23     Camden                  Lindenwold Public School District
# 24     Camden                           Magnolia School District
# 25     Camden                      Merchantville School District
# 26     Camden                        Mt. Ephraim School District
# 27     Camden                      Oaklyn Public School District
# 28     Camden  Pennsauken Township Board of Education School ...
# 29     Camden                          Pine Hill School District
# 30     Camden                   Runnemede Public School District
# 31     Camden                          Somerdale School District
# 32     Camden                  Sterling Regional School District
# 33     Camden                          Stratford School District
# 34     Camden                  Voorhees Township School District
# 35     Camden                 Waterford Township School District
# 36     Camden                   Winslow Township School District
# 37     Camden                          Woodlynne School District
# 38     Camden                      Hope Community Charter School
# 39     Camden                    Camden's Promise Charter School
# 40     Camden             LEAP Academy University Charter School
#
#    Economically Disadvantaged Students
# 0                                24.5%
# 1                                34.1%
# 2                                57.8%
# 3                                25.2%
# 4                                53.3%
# 5                                44.9%
# 6                                70.7%
# 7                                88.5%
# 8                                56.1%
# 9                                23.2%
# 10                               73.4%
# 11                               33.5%
# 12                               19.1%
# 13                               28.6%
# 14                               47.5%
# 15                               94.4%
# 16                               91.2%
# 17                               95.0%
# 18                               19.3%
# 19                               15.6%
# 20                                2.1%
# 21                               32.1%
# 22                               58.3%
# 23                               81.8%
# 24                               41.6%
# 25                               40.6%
# 26                               42.5%
# 27                               30.7%
# 28                               74.0%
# 29                               72.2%
# 30                               42.3%
# 31                               55.7%
# 32                               38.8%
# 33                               32.3%
# 34                               18.1%
# 35                               35.0%
# 36                               58.6%
# 37                               80.6%
# 38                               91.1%
# 39                               90.1%
# 40                               85.4%

# %%
njSch[['DIST_NAME','GEOID']]
DisXls1['c']=DisXls1.DIST_NAME.str.strip()
njSch['c']=njSch.DIST_NAME.str.strip()
# Out:
#                                    DIST_NAME    GEOID
# 0         Willingboro Public School District  3418000
# 1         South River Public School District  3415390
# 2    East Brunswick Township School District  3404110
# 3            Monroe Township School District  3410500
# 4              Dumont Public School District  3403990
# ..                                       ...      ...
# 334      Commercial Township School District  3403480
# 335   Maurice River Township School District  3409780
# 336           Lacey Township School District  3408100
# 337           Ocean Township School District  3412090
# 338                  Bayonne School District  3401260
#
# [339 rows x 2 columns]
# /tmp/ipykernel_1205/337144110.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DisXls1['c']=DisXls1.DIST_NAME.str.strip()

# %%
DisXls1[['DIST_NAME','Economically Disadvantaged Students']]
# Out:
#                                             DIST_NAME  \
# 0                      Audubon Public School District
# 1                          Barrington School District
# 2                     Bellmawr Public School District
# 3                      Berlin Borough School District
# 4                     Berlin Township School District
# 5           Black Horse Pike Regional School District
# 6                    Brooklawn Public School District
# 7                         Camden City School District
# 8             Camden County Technical School District
# 9                         Cherry Hill School District
# 10               Clementon Elementary School District
# 11                Collingswood Public School District
# 12     Eastern Camden County Regional School District
# 13               Gibbsboro Elementary School District
# 14                 Gloucester Township Public Schools
# 15  KIPP: Cooper Norcross, A New Jersey Nonprofit ...
# 16                                  Camden Prep, Inc.
# 17                    Mastery Schools of Camden, Inc.
# 18                     Haddon Heights School District
# 19                    Haddon Township School District
# 20                        Haddonfield School District
# 21                     Laurel Springs School District
# 22                           Lawnside School District
# 23                  Lindenwold Public School District
# 24                           Magnolia School District
# 25                      Merchantville School District
# 26                        Mt. Ephraim School District
# 27                      Oaklyn Public School District
# 28  Pennsauken Township Board of Education School ...
# 29                          Pine Hill School District
# 30                   Runnemede Public School District
# 31                          Somerdale School District
# 32                  Sterling Regional School District
# 33                          Stratford School District
# 34                  Voorhees Township School District
# 35                 Waterford Township School District
# 36                   Winslow Township School District
# 37                          Woodlynne School District
# 38                      Hope Community Charter School
# 39                    Camden's Promise Charter School
# 40             LEAP Academy University Charter School
#
#    Economically Disadvantaged Students
# 0                                24.5%
# 1                                34.1%
# 2                                57.8%
# 3                                25.2%
# 4                                53.3%
# 5                                44.9%
# 6                                70.7%
# 7                                88.5%
# 8                                56.1%
# 9                                23.2%
# 10                               73.4%
# 11                               33.5%
# 12                               19.1%
# 13                               28.6%
# 14                               47.5%
# 15                               94.4%
# 16                               91.2%
# 17                               95.0%
# 18                               19.3%
# 19                               15.6%
# 20                                2.1%
# 21                               32.1%
# 22                               58.3%
# 23                               81.8%
# 24                               41.6%
# 25                               40.6%
# 26                               42.5%
# 27                               30.7%
# 28                               74.0%
# 29                               72.2%
# 30                               42.3%
# 31                               55.7%
# 32                               38.8%
# 33                               32.3%
# 34                               18.1%
# 35                               35.0%
# 36                               58.6%
# 37                               80.6%
# 38                               91.1%
# 39                               90.1%
# 40                               85.4%

# %%
list(njSch.DIST_NAME.head(5))
list(DisXls1.DIST_NAME.head(5))
# Out:
# ['Willingboro Public School District',
#  'South River Public School District',
#  'East Brunswick Township School District',
#  'Monroe Township School District',
#  'Dumont Public School District']
# ['Audubon Public School District',
#  'Barrington School District',
#  'Bellmawr Public School District',
#  'Berlin Borough School District',
#  'Berlin Township School District']

# %%
a1 = pd.merge(njSch, DisXls1, left_on='c', right_on='c', how='outer', indicator=True)
a1
# Out:
#     NJDOE_ID_U                                    DIST_NAME_x UNSDLEA SD_TYPE  \
# 0      01-0010                Absecon Public Schools District   00660       U
# 1      41-0030             Allamuchy Township School District   00720       U
# 2      25-0050                     Allenhurst School District   00780       U
# 3      33-0060                    Alloway Twp School District   00810       U
# 4      41-0070                  Alpha Borough School District   00840       U
# ..         ...                                            ...     ...     ...
# 354    09-5840                       Woodbine School District   18090       U
# 355    23-5850            Woodbridge Township School District   18120       U
# 356    15-5860           Woodbury City Public School District   18150       U
# 357    07-5900                      Woodlynne School District   18270       U
# 358    33-5910  Woodstown-Pilesgrove Regional School District   18330       U
#
#        GEOID                                           geometry  \
# 0    3400660  POLYGON ((503391.012 215174.719, 503092.48 211...
# 1    3400720  POLYGON ((405096.281 772356.25, 406697.469 770...
# 2    3400780  POLYGON ((633359.751 511841.852, 633367.748 51...
# 3    3400810  POLYGON ((270406.342 276106.935, 272736.652 27...
# 4    3400840  POLYGON ((311826.54 670255.46, 311866.85 67014...
# ..       ...                                                ...
# 354  3418090  POLYGON ((403963.313 153137.25, 416762.281 142...
# 355  3418120  POLYGON ((548930.697 641772.802, 550167.286 64...
# 356  3418150  POLYGON ((311704.433 371407.465, 311619.079 37...
# 357  3418270  POLYGON ((326156.607 396643.803, 326112.001 39...
# 358  3418330  POLYGON ((250532.77 321539.57, 250508.82 32148...
#
#                                                  c CountyName  \
# 0                  Absecon Public Schools District        NaN
# 1               Allamuchy Township School District        NaN
# 2                       Allenhurst School District        NaN
# 3                      Alloway Twp School District        NaN
# 4                    Alpha Borough School District        NaN
# ..                                             ...        ...
# 354                       Woodbine School District        NaN
# 355            Woodbridge Township School District        NaN
# 356           Woodbury City Public School District        NaN
# 357                      Woodlynne School District     Camden
# 358  Woodstown-Pilesgrove Regional School District        NaN
#
#                    DIST_NAME_y Economically Disadvantaged Students     _merge
# 0                          NaN                                 NaN  left_only
# 1                          NaN                                 NaN  left_only
# 2                          NaN                                 NaN  left_only
# 3                          NaN                                 NaN  left_only
# 4                          NaN                                 NaN  left_only
# ..                         ...                                 ...        ...
# 354                        NaN                                 NaN  left_only
# 355                        NaN                                 NaN  left_only
# 356                        NaN                                 NaN  left_only
# 357  Woodlynne School District                               80.6%       both
# 358                        NaN                                 NaN  left_only
#
# [359 rows x 11 columns]

# %%
a1._merge.value_counts()
# Out:
# _merge
# left_only     318
# both           21
# right_only     20
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6,8))

# Convert the 'Economically Disadvantaged Students' column to numeric, handling NaN values
a1['Economically Disadvantaged Students'] = a1['Economically Disadvantaged Students'].apply(lambda x: float(x.replace('%', '')) if isinstance(x, str) else x)

a1.plot(ax=ax,figsize=(6,8),column='Economically Disadvantaged Students',legend=True,cmap='rainbow',
          scheme='natural_breaks',k=5, edgecolor='black',linewidth=2,legend_kwds= {"fmt": "{:.0f}%"})
ax.set_title('''% of Economically Disadvantaged Students
2024 - 2025 School Year''')
#ax.annotate('Note added to chart with minimum parameters', xy = (200000, 1000))
plt.figtext(0.35, 0.122,
            '''New Jersey, Department of Education
            2024 - 2025 Performance Reports Database - Excel
            Data from https://www.nj.gov/education/spr/download/
            ''',
            ha="center", fontsize=8, #bbox={"facecolor":"white", "alpha":0.5, "pad":5}
            )
# Out:
# <Axes: >
# Text(0.5, 1.0, '% of Economically Disadvantaged Students\n2024 - 2025 School Year')
# Text(0.35, 0.122, 'New Jersey, Department of Education\n            2024 - 2025 Performance Reports Database - Excel\n            Data from https://www.nj.gov/education/spr/download/\n            ')
